# %% [markdown]
# # Simulation Model for MARL

# %% [markdown]
# #### What are the machines and their tasks?

# %% [markdown]
# As a whole, the 3 machines need to complete as many(all?) of the product_requests in the total amount of steps. To complete a product_request, certain tasks need to be fulfilled like Ironing, Hardening, Sublimation, etc. The machines have task_modes whioch define what kind of tasks the machines can do. They are called task_modes because they are the current mode that the machine is in, and a machine can only run one task_mode at a time.

# %% [markdown]
# #### What do we want the machines/agents to predict?

# %% [markdown]
# When a machine is finished running a task_mode we want that machine to choose whether to stay idle or choose one of its possible task_modes to run for a product.
#
# (action) = (job_id, task_mode_id)
#
# OR
#
# (action) = IDLE

# %% [markdown]
# #### What do we want to optimize?

# %% [markdown]
# We want to minimize the amount of time it takes to complete the products, maximize the amount of products made, and minimize the total amount of energy used to make these products.

# %% [markdown]
# ### What kind of RL?
#
# We will be doing CTDE for MARL with 3 agents that correspond to the 3 machines.

# %% [markdown]
# ### Load Relevant Data

# %%
import pandas as pd
import json

import itertools
from collections import defaultdict

with open("data/Input_JSON_Schedule_Optimization.json") as f:
    data = json.load(f)


# we need a dictionary that maps task_mode_id to its power consumption list

task_mode_power_dict = {
    mode["id"]: mode["power"]
    for mode in data["task_modes"]
}
print(f"Task Mode to Power List Dictionary: {task_mode_power_dict}")

task_to_task_modes_dict = {
    task["id"]: task["task_modes"]
    for task in data["tasks"]
}
print(f"Task to Task Modes Dictionary: {task_to_task_modes_dict}")

mode_to_machines = defaultdict(set)
for m in data["machines"]:
    mid = m["id"]
    for mode_id in m["task_modes"]:
        mode_to_machines[mode_id].add(mid)
print(f"Mode to Machines Dictionary: {mode_to_machines}")

task_to_machines = {
    task: set(itertools.chain.from_iterable(mode_to_machines[mode] for mode in modes))
    for task, modes in task_to_task_modes_dict.items()
}
print(f"Task to Machines Dictionary: {task_to_machines}")
# Out:
# Task Mode to Power List Dictionary: {'Ironing TM1': [66, 258, 337, 285, 228, 227, 266, 354, 1194], 'Ironing TM3': [672, 1178, 884, 625, 621, 577, 560, 557, 311], 'Ironing TM4': [1109, 611, 1025, 643, 910, 695, 1654, 220, 1204, 210, 1129, 221], 'Harden[0.5] TM1': [1782, 1224, 1355, 1266, 1254, 1256, 1223, 1207, 1225, 1183, 1317, 187], 'Harden[0.5] TM4': [654, 785, 86, 53, 0], 'Harden[1] TM1': [1184, 861, 9, 223, 0, 0, 0, 0, 0, 0, 0, 0, 0, 53, 50, 38], 'Harden[1] TM2': [1167, 1167, 1167, 1196, 1155], 'Harden[1] TM5': [1687, 1681, 1674, 1665, 800, 1665, 757, 1539, 617], 'Harden[1.5] TM1': [1269, 1224, 1237, 1242, 1237, 1199, 1206, 1202, 1210, 1208, 1199, 1199, 1175, 1292, 483, 0, 0, 0, 0, 0, 0, 0, 0, 481, 1122], 'Harden[1.5] TM3': [510, 1624, 520, 1631, 506, 1628, 503, 3272, 922, 1213, 924, 1206, 948, 1201, 946], 'Harden[2] TM1': [724, 1118, 651, 1178, 578, 1265, 519, 1305, 502, 1331, 478, 1339, 456, 1356, 432, 1397, 408, 1420, 372, 1471, 155, 84, 66], 'Sublimation TM3': [78, 1029, 424, 330], 'Anti-Shrinkage TM2': [397, 549, 492, 65, 62, 59, 55]}
# Task to Task Modes Dictionary: {'Ironing': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'Harden[0.5]': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'Harden[1]': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'Harden[1.5]': ['Harden[1.5] TM1', 'Harden[1.5] TM3'], 'Harden[2]': ['Harden[2] TM1'], 'Sublimation': ['Sublimation TM3'], 'Anti-Shrinkage': ['Anti-Shrinkage TM2']}
# Mode to Machines Dictionary: defaultdict(<class 'set'>, {'Ironing TM4': {'MAQ118'}, 'Harden[2] TM1': {'MAQ118'}, 'Harden[1.5] TM3': {'MAQ118'}, 'Harden[0.5] TM4': {'MAQ118'}, 'Harden[1] TM5': {'MAQ118'}, 'Harden[1] TM1': {'MAQ119'}, 'Ironing TM3': {'MAQ119'}, 'Harden[0.5] TM1': {'MAQ119'}, 'Harden[1.5] TM1': {'MAQ119'}, 'Ironing TM1': {'MAQ120'}, 'Anti-Shrinkage TM2': {'MAQ120'}, 'Sublimation TM3': {'MAQ120'}})
# Task to Machines Dictionary: {'Ironing': {'MAQ120', 'MAQ119', 'MAQ118'}, 'Harden[0.5]': {'MAQ119', 'MAQ118'}, 'Harden[1]': {'MAQ119', 'MAQ118'}, 'Harden[1.5]': {'MAQ119', 'MAQ118'}, 'Harden[2]': {'MAQ118'}, 'Sublimation': {'MAQ120'}, 'Anti-Shrinkage': {'MAQ120'}}

# %%
import itertools
from collections import defaultdict

# ---------- 1) Index helpers from dataset ----------

# task -> [mode_ids]
task_to_modes = {t["id"]: list(t["task_modes"]) for t in data["tasks"]}

# mode_id -> power sequence
mode_power = {m["id"]: list(m["power"]) for m in data["task_modes"]}

# mode_id -> set(machines that can run it)
mode_to_machines = defaultdict(set)
for m in data["machines"]:
    mid = m["id"]
    for mode_id in m["task_modes"]:
        mode_to_machines[mode_id].add(mid)

# task -> set(machines that can run the task via any of its modes)
task_to_machines = {
    task: set(itertools.chain.from_iterable(mode_to_machines[mode] for mode in modes))
    for task, modes in task_to_modes.items()
}

# Constraints, kept for the environment to enforce later
order_constraints = []   # list of (first_task, second_task)
collision_constraints = set()  # set of frozenset({task1, task2})

for c in data.get("constraints", []):
    if c["type"] == "Order":
        order_constraints.append((c["parameter"]["first_task"], c["parameter"]["second_task"]))
    elif c["type"] == "Collision":
        t1 = c["parameter"]["task1"]; t2 = c["parameter"]["task2"]
        collision_constraints.add(frozenset({t1, t2}))


# ---------- 2) Build product recipes ----------
# product_id -> ordered list of (task_id, runs)
product_recipes = {}
for p in data["products"]:
    product_recipes[p["id"]] = [(x["task"], int(x["runs"])) for x in p["tasks"]]


# ---------- 3) Expand into concrete jobs (one per unit requested) ----------
jobs = []
job_counter = 1

for req in data["product_requests"]:
    product_id = req["product"]
    amount = int(req["amount"])
    deadline = req.get("deadline")  # may be absent

    # The route is copied per job so we can track progress independently
    recipe = product_recipes[product_id]

    for _ in range(amount):
        job_id = f"JOB{job_counter:04d}"
        job_counter += 1

        # Per-job route with progress fields
        route = []
        for task_id, runs in recipe:
            route.append({
                "task_id": task_id,
                "runs_required": runs,
                "runs_done": 0,
                "modes": list(task_to_modes[task_id]),               # allowed mode IDs for this task
                "eligible_machines": list(task_to_machines[task_id]) # machines that can run any mode of this task
            })

        jobs.append({
            "job_id": job_id,
            "product_id": product_id,
            "deadline": deadline,        # None if not provided
            "current_stage": 0,          # index in route; advance when runs_done == runs_required
            "route": route,              # ordered stages to complete
            "is_done": False,
        })

# ---------- 4) (Optional) Tiny peek at what you built ----------
def summarize_job(j):
    r = j["route"][j["current_stage"]]
    return {
        "job_id": j["job_id"],
        "product": j["product_id"],
        "deadline": j["deadline"],
        "stage_idx": j["current_stage"],
        "stage_task": r["task_id"],
        "stage_runs_done/req": f'{r["runs_done"]}/{r["runs_required"]}',
        "modes_available": r["modes"],
        "eligible_machines": r["eligible_machines"],
    }

for j in jobs:
    print(summarize_job(j))
# Out:
# {'job_id': 'JOB0001', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0002', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0003', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0004', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0005', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0006', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0007', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0008', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0009', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0010', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0011', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0012', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0013', 'product': 'WOVEN LABEL OURELA FABRIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0014', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0015', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0016', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0017', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0018', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0019', 'product': 'ESTORE RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0020', 'product': 'WOVEN LABEL OURELA CUT', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0021', 'product': 'WOVEN LABEL OURELA CUT', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0022', 'product': 'WOVEN LABEL OURELA CUT', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0023', 'product': 'WOVEN LABEL OURELA CUT', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0024', 'product': 'WOVEN LABEL OURELA CUT', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/3', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0025', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0026', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0027', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0028', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0029', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0030', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0031', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0032', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0033', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0034', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0035', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0036', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0037', 'product': 'GORGORÃO RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0038', 'product': 'GORGORÃO RIBBON W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0039', 'product': 'GORGORÃO RIBBON W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0040', 'product': 'GORGORÃO RIBBON W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0041', 'product': 'GORGORÃO RIBBON W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0042', 'product': 'GORGORÃO RIBBON W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0043', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0044', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0045', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0046', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0047', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0048', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0049', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0050', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0051', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0052', 'product': 'TAFFETA EMBLEM', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0053', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0054', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0055', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0056', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0057', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0058', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0059', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0060', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0061', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0062', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0063', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0064', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0065', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0066', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0067', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0068', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0069', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0070', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0071', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0072', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0073', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0074', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0075', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0076', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0077', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0078', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0079', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0080', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0081', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0082', 'product': 'PRINTED RIBBON', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0083', 'product': 'ELASTIC W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0084', 'product': 'ELASTIC W/ INSCR', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0085', 'product': 'ELASTIC W/ INSCR', 'deadline': 960, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0086', 'product': 'ROK ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[2]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[2] TM1'], 'eligible_machines': ['MAQ118']}
# {'job_id': 'JOB0087', 'product': 'ROK ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[2]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[2] TM1'], 'eligible_machines': ['MAQ118']}
# {'job_id': 'JOB0088', 'product': 'ROK ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[2]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[2] TM1'], 'eligible_machines': ['MAQ118']}
# {'job_id': 'JOB0089', 'product': 'SMOOTH STRAP(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0090', 'product': 'SMOOTH STRAP(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0091', 'product': 'SMOOTH STRAP(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0092', 'product': 'SMOOTH STRAP(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Ironing', 'stage_runs_done/req': '0/1', 'modes_available': ['Ironing TM1', 'Ironing TM3', 'Ironing TM4'], 'eligible_machines': ['MAQ120', 'MAQ118', 'MAQ119']}
# {'job_id': 'JOB0093', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0094', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0095', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0096', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0097', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0098', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0099', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0100', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0101', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0102', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0103', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0104', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0105', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0106', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0107', 'product': 'BRAIDED ELASTIC', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Anti-Shrinkage', 'stage_runs_done/req': '0/1', 'modes_available': ['Anti-Shrinkage TM2'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0108', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0109', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0110', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0111', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0112', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0113', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0114', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0115', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0116', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0117', 'product': 'PRINTED RIBBON  PES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Sublimation', 'stage_runs_done/req': '0/1', 'modes_available': ['Sublimation TM3'], 'eligible_machines': ['MAQ120']}
# {'job_id': 'JOB0118', 'product': 'SMOOTH ELASTIC(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[0.5]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0119', 'product': 'SMOOTH ELASTIC(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[0.5]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0120', 'product': 'SMOOTH ELASTIC(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[0.5]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0121', 'product': 'SMOOTH ELASTIC(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[0.5]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0122', 'product': 'SMOOTH ELASTIC(A)', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[0.5]', 'stage_runs_done/req': '0/1', 'modes_available': ['Harden[0.5] TM1', 'Harden[0.5] TM4'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0123', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0124', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0125', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0126', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0127', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0128', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0129', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0130', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0131', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}
# {'job_id': 'JOB0132', 'product': 'STRAP W/ STRIPES', 'deadline': None, 'stage_idx': 0, 'stage_task': 'Harden[1]', 'stage_runs_done/req': '0/2', 'modes_available': ['Harden[1] TM1', 'Harden[1] TM2', 'Harden[1] TM5'], 'eligible_machines': ['MAQ118', 'MAQ119']}

# %% [markdown]
# #### Simulation Rules

# %%
TOTAL_STEPS = 1152  # total steps in the simulation (6 days * 16 hours * (60/5) minutes)

class MachineRuntime:
    def __init__(self):
        self.busy = False # is the machine currently running a task_mode
        self.job_id = None  # which job the machine is working on
        self.task_mode_id = None # which task_mode the machine is running
        self.remaining_task_mode_steps = 0 # remaining steps for the current task_mode
        self.task_mode_step = 0  # The "step"/index of the current task_mode

    def start_task_mode(self, job_id, task_mode_id):
        """
        Start a new task_mode on this machine.
        """
        self.busy = True
        self.job_id = job_id
        self.task_mode_id = task_mode_id

        # Get the power list for each step this task_mode
        power_list = task_mode_power_dict[task_mode_id] 
        self.remaining_task_mode_steps = len(power_list)

        self.task_mode_step = 0 # indexes through the power list

        
    def step_power(self, power_seq):
        """
        Return power consumption for this step.
        If we're in a task_mode, 
        """
        if not self.busy:
            return 0 
        
        power_list = task_mode_power_dict[self.task_mode_id]
        power = power_list[self.task_mode_step]  # get current step power
        
        self.task_mode_step += 1
        self.remaining_task_mode_steps -= 1
        if self.remaining_task_mode_steps == 0:
            # task is complete
            self._reset()
        return power
    
    def _reset(self):

        self.busy = False
        self.job_id = None
        self.task_mode_id = None
        self.remaining_task_mode_steps = 0
        self.task_mode_step = 0

# %%
# Example usage

m = MachineRuntime()
m.start_task_mode("JOB1", "Ironing TM1")
while m.busy:
    power = m.step_power(None)
    print(f"Step power: {power}")
# Out:
# Step power: 66
# Step power: 258
# Step power: 337
# Step power: 285
# Step power: 228
# Step power: 227
# Step power: 266
# Step power: 354
# Step power: 1194
